# %%
def func_2(a: int, b: int):
    return a * b



func_2('a', 3)
# Out:
# 'aaa'

# %%
func_2([1, 2], 3)
# Out:
# [1, 2, 1, 2, 1, 2]

# %%
func_2
# Out:
# <function __main__.func_1(a: int, b: int)>

# %%
def func_3():
    return func_4()

def func_4():
    return 'running func_4'

# %%
func_3()
# Out:
# 'running func_4'

# %%
def func_5():
    return func_6()

func_5()

def func_6():
    return 'running func 6'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 def func_5():
#       2     return func_6()
#       3
# ----> 4 func_5()
#       5
#       6 def func_6():
#       7     return 'running func 6'
#
# Cell In[10], line 2, in func_5()
#       1 def func_5():
# ----> 2     return func_6()
#
# NameError: name 'func_6' is not defined

# %%
type(func_5)
# Out:
# function

# %%
my_func = func_4

# %%
func_4()
# Out:
# 'running func_4'

# %%
my_func()
# Out:
# 'running func_4'

# %%
lambda x: x**2
# Out:
# <function __main__.<lambda>(x)>

# %%
fn1 = lambda x: x**2

# %%
fn1(2)
# Out:
# 4
